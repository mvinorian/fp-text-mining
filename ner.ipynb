# %% [markdown]
# ## Import Library

# %%
import pandas as pd

from transformers import pipeline, AutoTokenizer, AutoModelForTokenClassification
# Out:
# WARNING:tensorflow:From c:\Users\mvinorian\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Dataset Information

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#                        judul            asal  \
# 0         Legenda Danau Toba  Sumatera Utara
# 1               Puteri Hijau  Sumatera Utara
# 2    Batu Gantung Danau Toba  Sumatera Utara
# 3  Sampuraga Si Anak Durhaka  Sumatera Utara
# 4            Si Buyung Besar  Sumatera Utara
#
#                                                 text
# 0  Di sebuah desa di wilayah Sumatera, hidup seor...
# 1  Sekitar abad 14 dan 15 masehi , berdiri keraja...
# 2  Pada zaman dahulu kala, terdapat satu keluarga...
# 3  Pada zaman dulu, hiduplah seorang janda tua da...
# 4  Pada zaman dahulu kala penduduk pantai pun mas...

# %%
df = df[['judul', 'asal', 'text']]
df.head()
# Out:
#                        judul            asal  \
# 0         Legenda Danau Toba  Sumatera Utara
# 1               Puteri Hijau  Sumatera Utara
# 2    Batu Gantung Danau Toba  Sumatera Utara
# 3  Sampuraga Si Anak Durhaka  Sumatera Utara
# 4            Si Buyung Besar  Sumatera Utara
#
#                                                 text
# 0  Di sebuah desa di wilayah Sumatera, hidup seor...
# 1  Sekitar abad 14 dan 15 masehi , berdiri keraja...
# 2  Pada zaman dahulu kala, terdapat satu keluarga...
# 3  Pada zaman dulu, hiduplah seorang janda tua da...
# 4  Pada zaman dahulu kala penduduk pantai pun mas...

# %% [markdown]
# ## Implementasi NER

# %%
pipe = pipeline("token-classification", model="cahya/xlm-roberta-large-indonesian-NER")
tokenizer = AutoTokenizer.from_pretrained("cahya/xlm-roberta-large-indonesian-NER")
model = AutoModelForTokenClassification.from_pretrained("cahya/xlm-roberta-large-indonesian-NER")
# Out:
# Some weights of the model checkpoint at cahya/xlm-roberta-large-indonesian-NER were not used when initializing XLMRobertaForTokenClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at cahya/xlm-roberta-large-indonesian-NER were not used when initializing XLMRobertaForTokenClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
nlp = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# %%
df.shape
# Out:
# (220, 3)

# %% [markdown]
# ### Fungsi

# %%
manual_entities = {
    "Petani": "PER",
    "Puteri": "PER",
    "Sang": "PER",
    "Si": "PER",
    "Raja": "PER",
    "Ratu": "PER",
    "Pangeran": "PER",
    "Ayah": "PER",
    "Ibu": "PER",
}

def split_text(text, tokenizer, max_length=512):
    tokens = tokenizer.tokenize(text)
    token_chunks = [tokens[i:i+max_length] for i in range(0, len(tokens), max_length)]
    text_chunks = [tokenizer.convert_tokens_to_string(chunk) for chunk in token_chunks]
    return text_chunks

def apply_ner(text):
    text_chunks = split_text(text, tokenizer)
    results = []
    for chunk in text_chunks:
        ner_results = nlp(chunk)
        results.extend(ner_results)
    return results

def add_manual_entities(text, ner_results, manual_entities):
    words = text.split()
    for i, word in enumerate(words):
        if word in manual_entities:
            entity = {
                'word': word,
                'entity_group': manual_entities[word],
                'start': text.find(word),
                'end': text.find(word) + len(word)
            }
            ner_results.append(entity)
    return ner_results

# %%
df['ner_results'] = df['text'].apply(lambda x: add_manual_entities(x, apply_ner(x), manual_entities))
df.head()
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (931 > 512). Running this sequence through the model will result in indexing errors
#                        judul            asal  \
# 0         Legenda Danau Toba  Sumatera Utara
# 1               Puteri Hijau  Sumatera Utara
# 2    Batu Gantung Danau Toba  Sumatera Utara
# 3  Sampuraga Si Anak Durhaka  Sumatera Utara
# 4            Si Buyung Besar  Sumatera Utara
#
#                                                 text  \
# 0  Di sebuah desa di wilayah Sumatera, hidup seor...
# 1  Sekitar abad 14 dan 15 masehi , berdiri keraja...
# 2  Pada zaman dahulu kala, terdapat satu keluarga...
# 3  Pada zaman dulu, hiduplah seorang janda tua da...
# 4  Pada zaman dahulu kala penduduk pantai pun mas...
#
#                                          ner_results
# 0  [{'entity_group': 'GPE', 'score': 0.9980665, '...
# 1  [{'entity_group': 'DAT', 'score': 0.68840194, ...
# 2  [{'entity_group': 'CRD', 'score': 0.9936027, '...
# 3  [{'entity_group': 'PER', 'score': 0.9767194, '...
# 4  [{'entity_group': 'CRD', 'score': 0.74330723, ...

# %%
df.shape
# Out:
# (220, 4)

# %%
def find_words_with_label(ner_results, label):
    return list(set(ent['word'] for ent in ner_results if ent['entity_group'] == label))

# %%
df['persons'] = df['ner_results'].apply(lambda x: find_words_with_label(x, 'PER'))

# %%
df.head(50)
# Out:
#                                                 judul                 asal  \
# 0                                  Legenda Danau Toba       Sumatera Utara
# 1                                        Puteri Hijau       Sumatera Utara
# 2                             Batu Gantung Danau Toba       Sumatera Utara
# 3                           Sampuraga Si Anak Durhaka       Sumatera Utara
# 4                                     Si Buyung Besar       Sumatera Utara
# 5                                        Jibau Malang       Sumatera Utara
# 6                                  Tuah Burung Merbak       Sumatera Utara
# 7               Partiga Tiga Sipunjung Dan Anggaranim       Sumatera Utara
# 8                                Cerita Raja Narasaon       Sumatera Utara
# 9                       Sipakpak Kunal Dan Nagai Sori       Sumatera Utara
# 10                           Datu Dalu dan Sang Maima       Sumatera Utara
# 11                      Cerita Pelleng Peneppuh Babah       Sumatera Utara
# 12                              Cerita Datu Kandibata       Sumatera Utara
# 13                                 Kisah Sitagan Bulu       Sumatera Utara
# 14                                   Kisah Lubuk Emas       Sumatera Utara
# 15                                        Raja Empedu     Sumatera Selatan
# 16                                     Si Pahit Lidah     Sumatera Selatan
# 17                 Danau Singkarak dan Sungai Ombilin       Sumatera Barat
# 18                                      Malin Kundang       Sumatera Barat
# 19                                      Siamang Putih       Sumatera Barat
# 20                                              Bayo'       Sumatera Barat
# 21                                   Rawang Tengkuluk       Sumatera Barat
# 22                             Legenda Bukti Fafinesu  Nusa Tenggara Timur
# 23                                   Kisah Doyan Nada  Nusa Tenggara Barat
# 24                               Asal Mula Pulau Nusa    Kalimantan Tengah
# 25                               Asal Usul Ikan Patin    Kalimantan Tengah
# 26                                   Ambun dan Rimbun    Kalimantan Tengah
# 27                                      Gunung Arjuna           Jawa Timur
# 28                      Jaka Budug dan Putri Kemuning           Jawa Timur
# 29                                      Putri Kandita           Jawa Barat
# 30                                       Keramat Riak             Bengkulu
# 31           Pangeran Pande Gelang dan Putri Cadasari               Banten
# 32                               Puteri Niweri Gading                 Aceh
# 33                                      Banta Seudang                 Aceh
# 34                               Kisah Malai Sembilan       Sumatera Utara
# 35                               Asal Usul Danau Biru       Sumatera Barat
# 36                          Batu Belah Batu Betangkup                 Riau
# 37                              Legenda Danau Sentani                Papua
# 38                                   Ende Gunung Meja  Nusa Tenggara Timur
# 39  Legenda Gunung Rinjani: Kisah Asal-usul Segara...  Nusa Tenggara Barat
# 40                        Putri Anggun dan Raja Hutan     Kalimantan Timur
# 41                        Sang Kancil dan Gajah Sakti     Kalimantan Barat
# 48  Di sebuah desa kecil di Sunda, hiduplah seoran...
# 49  Pada Zaman dahulu, disaat kota Tasik masih ber...
#
#                                           ner_results  \
# 0   [{'entity_group': 'GPE', 'score': 0.9980665, '...
# 1   [{'entity_group': 'DAT', 'score': 0.68840194, ...
# 2   [{'entity_group': 'CRD', 'score': 0.9936027, '...
# 3   [{'entity_group': 'PER', 'score': 0.9767194, '...
# 4   [{'entity_group': 'CRD', 'score': 0.74330723, ...
# 5   [{'entity_group': 'LOC', 'score': 0.896115, 'w...
# 6   [{'entity_group': 'GPE', 'score': 0.93900275, ...
# 7   [{'entity_group': 'GPE', 'score': 0.99705803, ...
# 8   [{'entity_group': 'ORD', 'score': 0.52149594, ...
# 9   [{'entity_group': 'GPE', 'score': 0.78550386, ...
# 10  [{'entity_group': 'LOC', 'score': 0.6474602, '...
# 11  [{'entity_group': 'CRD', 'score': 0.58503795, ...
# 12  [{'entity_group': 'PER', 'score': 0.420236, 'w...
# 13  [{'entity_group': 'PER', 'score': 0.99573314, ...
# 14  [{'entity_group': 'GPE', 'score': 0.5634431, '...
# 15  [{'entity_group': 'GPE', 'score': 0.99784046, ...
# 16  [{'entity_group': 'PER', 'score': 0.9778919, '...
# 17  [{'entity_group': 'GPE', 'score': 0.9977925, '...
# 18  [{'entity_group': 'GPE', 'score': 0.562069, 'w...
# 19  [{'entity_group': 'PER', 'score': 0.9627406, '...
# 20  [{'entity_group': 'LOC', 'score': 0.93639326, ...
# 21  [{'entity_group': 'LOC', 'score': 0.97500324, ...
# 22  [{'entity_group': 'GPE', 'score': 0.9081008, '...
# 23  [{'entity_group': 'GPE', 'score': 0.9426124, '...
# 24  [{'entity_group': 'PER', 'score': 0.9979259, '...
# 25  [{'entity_group': 'GPE', 'score': 0.9981098, '...
# 26  [{'entity_group': 'GPE', 'score': 0.9983622, '...
# 27  [{'entity_group': 'WOA', 'score': 0.3785158, '...
# 28  [{'entity_group': 'GPE', 'score': 0.96656334, ...
# 29  [{'entity_group': 'GPE', 'score': 0.90204865, ...
# 30  [{'entity_group': 'CRD', 'score': 0.662217, 'w...
# 31  [{'entity_group': 'GPE', 'score': 0.9858426, '...
# 32  [{'entity_group': 'REG', 'score': 0.6184552, '...
# 33  [{'entity_group': 'PER', 'score': 0.87450236, ...
# 34  [{'entity_group': 'GPE', 'score': 0.981036, 'w...
# 35  [{'entity_group': 'GPE', 'score': 0.7086939, '...
# 36  [{'entity_group': 'PER', 'score': 0.9417926, '...
# 37  [{'entity_group': 'PRD', 'score': 0.5771613, '...
# 38  [{'entity_group': 'PER', 'score': 0.99669147, ...
# 39  [{'entity_group': 'GPE', 'score': 0.9657079, '...
# 40  [{'entity_group': 'LOC', 'score': 0.56922597, ...
# 41  [{'entity_group': 'GPE', 'score': 0.9070744, '...
# 42  [{'entity_group': 'GPE', 'score': 0.9875891, '...
# 43  [{'entity_group': 'PER', 'score': 0.99691325, ...
# 44  [{'entity_group': 'LOC', 'score': 0.97628605, ...
# 45  [{'entity_group': 'GPE', 'score': 0.9961132, '...
# 46  [{'entity_group': 'GPE', 'score': 0.7222541, '...
# 47  [{'entity_group': 'NOR', 'score': 0.79872036, ...
# 48  [{'entity_group': 'GPE', 'score': 0.9994398, '...
# 49  [{'entity_group': 'GPE', 'score': 0.9553315, '...
#
#                                               persons
# 0   [Pu, Kanda, teri, Petani, ni, Putera, Peta, Pu...
# 1   [ri Hij, Mambang Jazid, jazid, putri hijau, Su...
# 2        [Toki, Sang, uni, Ayah, Ser, seruni, Seruni]
# 3   [Sampura, Ibu, Sang, sampura, sampuraga, Sampu...
# 4   [Buyung, Sang, si Buyung Besar, Datuk, Bu, put...
# 5   [si Jibau, si Nogong, bunda Siti Ensah, Datuk ...
# 6   [Pu, Wak Pawang Merbuk, Wak Pawang Berbuk, Ibu...
# 7   [Sang, PARTIGA TIGA SIPUNJUNG, Si, NAN SORMA, ...
# 8   [Datu Pejek, Siboru Bidinglaut, Narasaon, Sang...
# 9   [Margolang, Sipakpak Kunal, Raja Lela, Nagai S...
# 10  [Sang Maima, Sang, Siboru Hombing, PULUNGANTUA...
# 11  [meteka, Bincala Balekat, raja Bulbelen, Peduk...
# 12  [s, Si Beru Tanda, si Beru Tandang Maeriah, si...
# 13  [, Boru Nainggolan, Datu Parngongo, SI Taganbu...
# 14  [Margolang, Pu, Mah, Ha, Tuanku Puteri, Putera...
# 15  [Raja Kubu, Raja Pangeran Mas, Raja, Pangeran,...
# 16  [Sang, Pagar Bumi, Lidah, si Empat Mata, Mata,...
# 17  [Indra, Ibu, la, Pak Buyung, Ayah, ndra, l, Ta...
# 18  [Mande Rubayah, Rubayah, Man, Malin Kundang, I...
# 19  [Pu, i, Rus, Rustam, Sutan Rumandang, ang, Uda...
# 20  [Mak Ipe, Bayo’, Ipe, iti, S, Mak Ipeh, Mak Siti]
# 21  [Mak Siyah, Ibu, Tek, Tek Kan, Tek Kanah, iti,...
# 22                [Seko, Abatan, Ibu, Saku, Ayah, Si]
# 23  [Limandaru, Ibu, Patih, yan Nada, Doyan Nada, ...
# 24  [Naga Nu, sa, ang, Naga Nusa, Sal, kan Jelawat...
# 25  [Leniris, niri, ri, Simbun, Ni, Labih, Ari, Ay...
# 26  [Rimbun, Rim, Ibu, un, Amb, R, Ambun, Sang, bu...
# 27  [Pandu, Bata, Den, Batara Togo, Prabu Pandu, M...
# 28  [ri Kemuning, Sang, Prabu Aryo Seto, Putri Kem...
# 29  [Prabu Siliwangi, Bagi, Putri Kandita, Sang, S...
# 30  [Syekh Abdullatif, Raja Riak Bakau, Raja Riak ...
# 31  [Pu, Puti Arum, Aki, Sang, Pengeran Cunihin, P...
# 32  [Mah, Pak, Raja Muda, Arnat Mude, Silenggang R...
# 33  [Mak Toyo, Seudang, Ban, ayah, Raja, Banta Seu...
# 34                                        [Datu Musa]
# 35                                       [Sari, Rama]
# 36                            [Minah, Bu Minah, Mina]
# 37                                                 []
# 38                        [Me, Meja, Iya, ja, Wongge]
# 39                     [Jaka Daha, Dewi Anjani, Lalu]
# 40  [Adi, ri Anggun, gun, Anggun, Raja Hutan, Raja...
# 41                                [Sang Kancil, Sang]
# 42                    [Rara Anteng, Bima, Jaka Seger]
# 43  [Mahesa Sur, Dewi Kilisuci, Lembu Suro, Sang, ...
# 44                                      [Raden Cilik]
# 45              [Panji, ji, Pan, Panji Asmoro Bangun]
# 46                       [Jaka Sempor, Raden Purnama]
# 47  [Pantai Selatan, Selatan, Kyai Keramat, Tumeng...
# 48            [Ratu, Ratu Puyang Adong, Puyang Adong]
# 49        [Rangga Gading, E, Eyang, Ki Rangga Gading]

# %%
df.to_csv('ner_results2.csv', index=False)
